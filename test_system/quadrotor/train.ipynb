# %%
# In[1]

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3D
import matplotlib.animation as animation
import quadrotor_A2C_traj as train_model
import numpy as np


# In[2]

if __name__ == '__main__':
    arrive_time = 30
    hover_time = 2
    quadrotor_env = train_model.Environment()
    data, distance = quadrotor_env.run(arrive_time, hover_time)
    np.save('./test_system/quadrotor/trained_net/flight_data.npy', data)
    np.save('./test_system/quadrotor/trained_net/distance_data.npy', distance)
    
    t = np.arange(0,arrive_time + hover_time,0.01)

    def update_lines(num, data, line):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2, :num])
        return line

    # Attaching 3D axis to the figure
    fig1 = plt.figure(num = 1, figsize=(plt.figaspect(1)))
    ax = Axes3D(fig1)

    x = data[0,:,9]
    y = data[0,:,10]
    z = data[0,:,11]
    data_plot = np.array([x,y,z])
    
    line = ax.plot(x, y, z)[0]

    # Setting the axes properties
    ax.set_xlim3d([-50, 50])
    ax.set_ylim3d([-50, 50])
    ax.set_zlim3d([0, 100])

    ax.set_ylabel('Y')
    ax.set_xlabel('X')
    ax.set_zlabel('Z')

    ax.set_title('Trajectory')

    # Creating the Animation object
    line_ani = animation.FuncAnimation(fig1, update_lines, 25, fargs=(data_plot, line),
                                    interval=50, blit=False)
    line_ani.save('./test_system/quadrotor/trained_net/flight.gif', writer='pillow', fps=60)

    
    fig2 = plt.figure(num = 2, figsize=(16,9))
    ax1 = fig2.add_subplot(2, 3, 1)
    plt.plot(data[0,:,9],
                data[0,:,10])
    plt.xlim(-10,10)
    plt.ylim(-10,10)
    plt.title('x-y Postition')
    plt.xlabel('X axis [m]')
    plt.ylabel('Y axis [m]')
    plt.grid()
    
    ax2 = fig2.add_subplot(2, 3, 2)
    plt.plot(t,data[0,:,11])
    plt.title('Height')
    plt.xlabel('Time [s]')
    plt.ylabel('Height [m]')
    plt.grid()

    ax3 = fig2.add_subplot(2, 3, 3)
    plt.plot(t,data[0,:,6]*180/np.pi,
                t,data[0,:,7]*180/np.pi,
                t,data[0,:,8]*180/np.pi)
    plt.title('Angle')
    plt.xlabel('Time [s]')
    plt.ylabel('Angle [deg]')
    plt.legend(['x(phi)','y(theta)','z(psi)'])
    plt.grid()

    ax4 = fig2.add_subplot(2, 3, 4)
    plt.plot(t, data[0,:,0]*180/np.pi,
                t, data[0,:,1]*180/np.pi,
                t, data[0,:,2]*180/np.pi)
    plt.title('Angular Velocity(body)')
    plt.xlabel('Time [s]')
    plt.ylabel('Angular Velocity(body) [deg/s]')
    plt.legend(['x(phi)','y(theta)','z(psi)'])
    plt.grid()
    
    ax3 = fig2.add_subplot(2, 3, 5)
    plt.plot(t,distance[0,:])
    plt.title('Distance off from guided trajectory')
    plt.xlabel('Time [s]')
    plt.ylabel('Distance [m]')
    plt.grid()

    fig2.savefig('./test_system/quadrotor/trained_net/flight_data.png')
    
    plt.show()
# Out:
# cpu
# ------crashed to ground------
# 1 episode, 1 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.05
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 2 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.11
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 4 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.16
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 5 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.22
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 12 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.27
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 14 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.33
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 15 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.38
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 16 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.44
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 17 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.49
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 19 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.55
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 21 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.6
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 26 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.66
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 29 slot: 0.11 [s]
# slot_reward: 1.7569
# distance: 0.1348m
# reward_mean: 0.71
# reward_max: 1.76
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 8 slot: 0.12 [s]
# slot_reward: 1.766
# distance: 0.147m
# reward_mean: 0.77
# reward_max: 1.77
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 25 slot: 0.12 [s]
# slot_reward: 1.766
# distance: 0.147m
# reward_mean: 0.82
# reward_max: 1.77
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 6 slot: 0.14 [s]
# slot_reward: 1.7776
# distance: 0.1715m
# reward_mean: 0.88
# reward_max: 1.78
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 7 slot: 0.15 [s]
# slot_reward: 1.7809
# distance: 0.1838m
# reward_mean: 0.94
# reward_max: 1.78
# reward_min: 0.0
# ------crashed to ground------
# 1 episode, 31 slot: 0.19 [s]
# slot_reward: 1.7845
# distance: 0.2328m
# reward_mean: 0.99
# reward_max: 1.78
# reward_min: 0.0
# ------crashed to ground------
# 2 episode, 23 slot: 0.21 [s]
# slot_reward: 1.7823
# distance: 0.2573m
# reward_mean: 1.05
# reward_max: 1.78
# reward_min: 0.0
# ------crashed to ground------
# 2 episode, 2 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -27.31
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 4 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -55.66
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 5 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -84.02
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 12 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -112.37
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 14 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -140.72
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 15 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -169.08
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 16 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -197.43
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 26 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -225.79
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 29 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -254.14
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 8 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -282.5
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 20 slot: 0.24 [s]
# slot_reward: 1.7759
# distance: 0.294m
# reward_mean: -282.44
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 6 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -310.79
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 10 slot: 0.28 [s]
# slot_reward: 1.7633
# distance: 0.343m
# reward_mean: -310.74
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 31 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -311.31
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 23 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -311.88
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 2 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -340.28
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 4 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -368.69
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 14 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -397.1
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 16 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -425.51
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 26 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -453.92
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 8 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -482.33
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 20 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -482.9
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 6 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -511.31
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 7 slot: 0.21 [s]
# slot_reward: -474.4081
# distance: 0.2573m
# reward_mean: -526.19
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 1 slot: 0.28 [s]
# slot_reward: -355.3794
# distance: 0.3431m
# reward_mean: -537.35
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 2 episode, 10 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -537.92
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 23 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -566.33
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 14 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -594.73
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 26 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -623.14
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 8 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -651.55
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -679.96
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 6 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -708.37
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 7 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -680.53
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 1 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -652.69
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 10 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -652.69
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 14 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -652.69
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 23 slot: 0.12 [s]
# slot_reward: -831.5674
# distance: 0.147m
# reward_mean: -650.32
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 26 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -650.32
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 8 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -650.32
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -650.32
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 6 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -650.32
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 3 episode, 7 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -650.32
# reward_max: 1.78
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 1 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -678.73
# reward_max: 1.76
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 10 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -678.73
# reward_max: 1.76
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 16 slot: 0.33 [s]
# slot_reward: -301.2864
# distance: 0.4045m
# reward_mean: -688.2
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 23 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -716.05
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 26 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 6 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 1 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 23 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 4 episode, 6 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.89
# reward_max: -16.42
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 22 slot: 0.81 [s]
# slot_reward: 1.4842
# distance: 1.0065m
# reward_mean: -743.33
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 1 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -743.33
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 23 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -756.86
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -774.1
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 8 slot: 0.35 [s]
# slot_reward: -283.9796
# distance: 0.4286m
# reward_mean: -782.47
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 22 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -754.62
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 5 episode, 13 slot: 1.0 [s]
# slot_reward: 1.3871
# distance: 1.192m
# reward_mean: -726.23
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 6 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -726.23
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 6 episode, 23 slot: 0.14 [s]
# slot_reward: -712.5082
# distance: 0.1715m
# reward_mean: -720.14
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 6 episode, 22 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -720.14
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 6 episode, 13 slot: 0.11 [s]
# slot_reward: -16.4249
# distance: 0.1348m
# reward_mean: -692.3
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 6 episode, 20 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -720.14
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 6 episode, 22 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -747.98
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 7 episode, 13 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -747.98
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 7 episode, 22 slot: 0.11 [s]
# slot_reward: -907.334
# distance: 0.1348m
# reward_mean: -747.98
# reward_max: 1.48
# reward_min: -907.33
# ------crashed to ground------
# 7 episode, 7 slot: 0.72 [s]
# slot_reward: -137.3493
# distance: 0.8779m
# reward_mean: -726.28
# reward_max: 1.48
# reward_min: -907.33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/casadi/casadi.py in &lt;lambda&gt;(self, name, value)
#    6289         __swig_setmethods__.update(getattr(_s, &#39;__swig_setmethods__&#39;, {}))
# -&gt; 6290     __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291     __swig_getmethods__ = {}
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# &lt;ipython-input-1-5b9d13c5e63e&gt; in &lt;module&gt;
#      13     hover_time = 2
#      14     quadrotor_env = train_model.Environment()
# ---&gt; 15     data, distance = quadrotor_env.run(arrive_time, hover_time)
#      16     np.save(&#39;./test_system/quadrotor/trained_net/flight_data.npy&#39;, data)
#      17     np.save(&#39;./test_system/quadrotor/trained_net/distance_data.npy&#39;, distance)
#
# ~/Desktop/develop/ros-torch-control/test_system/quadrotor/quadrotor_A2C_traj.py in run(self, arrive_time, hover_time)
#     249                 for i in range(NUM_PROCESSES):
#     250                     obs_np[i], reward_np[i], done_np[i], done_info_np[i], distance_np[i]\
# --&gt; 251                        = envs[i].step(actions[i], each_step[i])
#     252
#     253                     # train data 의 저장 -&gt; reward &amp; replay 위함
#
# ~/Desktop/develop/ros-torch-control/test_system/quadrotor/quadrotor_traj.py in step(self, action, step, dt)
#     132
#     133         # calculate next step state
# --&gt; 134         res = scipy.integrate.solve_ivp(
#     135             fun=lambda t, x: np.array(self.rhs(self.xi, self.u, self.p)).reshape(-1),
#     136                 t_span=[self.t, self.t+dt], t_eval=[self.t+dt], y0=self.xi
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574     status = None
#     575     while status is None:
# --&gt; 576         message = solver.step()
#     577
#     578         if solver.status == &#39;finished&#39;:
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in step(self)
#     179         else:
#     180             t = self.t
# --&gt; 181             success, message = self._step_impl()
#     182
#     183             if not success:
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --&gt; 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      65
#      66     y_new = y + h * np.dot(K[:-1].T, B)
# ---&gt; 67     f_new = fun(t + h, y_new)
#      68
#      69     K[-1] = f_new
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --&gt; 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---&gt; 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# ~/Desktop/develop/ros-torch-control/test_system/quadrotor/quadrotor_traj.py in &lt;lambda&gt;(t, x)
#     133         # calculate next step state
#     134         res = scipy.integrate.solve_ivp(
# --&gt; 135             fun=lambda t, x: np.array(self.rhs(self.xi, self.u, self.p)).reshape(-1),
#     136                 t_span=[self.t, self.t+dt], t_eval=[self.t+dt], y0=self.xi
#     137         )
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/casadi/casadi.py in __call__(self, *args, **kwargs)
#   13442       if len(args)&gt;0:
#   13443     # Ordered inputs -&gt; return tuple
# &gt; 13444         ret = self.call(args)
#   13445         if len(ret)==0:
#   13446           return None
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/casadi/casadi.py in call(self, *args)
#   12322
#   12323         &quot;&quot;&quot;
# &gt; 12324         return _casadi.Function_call(self, *args)
#   12325
#   12326
#
# SystemError: &lt;built-in function Function_call&gt; returned a result with an error set
