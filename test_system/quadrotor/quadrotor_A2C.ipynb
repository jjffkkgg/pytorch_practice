# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd ~/../content/drive/My Drive/git/pytorch_practice/test_system/quadrotor
# !pip install casadi
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/git/pytorch_practice/test_system/quadrotor
# Collecting casadi
#   Downloading https://files.pythonhosted.org/packages/62/55/61a10cad304f80621836b811d70666c06a9c22863768cc23edd6904bb35f/casadi-3.5.5-cp36-none-manylinux1_x86_64.whl (34.2MB)
#      |████████████████████████████████| 34.2MB 89kB/s
# Installing collected packages: casadi
# Successfully installed casadi-3.5.5

# %%
# from __future__ import annotations
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
import copy
from quadrotor import QuadRotorEnv 


use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
'''Global Variables'''
GAMMA = 0.99                # 시간할인율
MAX_STEPS = 2000             # 1에피소드 당 최대 단계 수 (0.01 second per step)
NUM_EPISODES = 10000         # 최대 에피소드 수

NUM_PROCESSES = 32          # 동시 실행 환경 수
NUM_ADVANCED_STEP = 50       # 총 보상을 계산할 때 Advantage 학습(action actor)을 할 단계 수

VALUE_LOSS_COEFF = 0.5
ENTROPY_COEFF = 0.05        # Local min 에서 벗어나기 위한 엔트로피 상수
MAX_GRAD_NORM = 0.5

# %%
class RolloutStorage(object):
    '''Advantage 학습에 사용할 메모리 클래스'''
    def __init__(self, num_steps: int, num_processes: int, obs_shape: int) -> None:
        '''initialize tensors for work'''
        self.observations = torch.zeros(num_steps + 1, num_processes, obs_shape).to(device)        # obs tensor init
        self.masks = torch.ones(num_steps + 1, num_processes, 1).to(device)                        # mask -> is end of episode ? 0 | 1
        self.rewards = torch.zeros(num_steps, num_processes, 1).to(device)  
        self.actions = torch.zeros(num_steps, num_processes, 1).long().to(device)

        # 할인 총 보상(J(theta,s_t))저장하는 메모리 (Actor)
        self.returns = torch.zeros(num_steps + 1, num_processes, 1).to(device)
        self.index = 0              # insert 하는 index          

    def insert(self, current_obs, action, reward, mask) -> None:
        '''현재 인덱스 위치에 transition을 저장'''
        self.observations[self.index + 1].copy_(current_obs)        # torch.size([6, 32, 12])
        self.masks[self.index + 1].copy_(mask)
        self.rewards[self.index].copy_(reward)
        self.actions[self.index].copy_(action)

        self.index = (self.index + 1) % NUM_ADVANCED_STEP  # 인덱스 값 업데이트

    def after_update(self):
        '''Advantage학습 단계만큼 단계가 진행되면 가장 새로운 transition을 index0에 저장'''
        self.observations[0].copy_(self.observations[-1])
        self.masks[0].copy_(self.masks[-1])

    def compute_returns(self, next_value):
        '''Advantage학습 범위 안의 각 단계에 대해 할인 총보상(J)을 계산'''

        # 주의 : 5번째 단계부터 거슬러 올라오며 계산
        # 주의 : 5번째 단계가 Advantage1, 4번째 단계는 Advantage2가 됨
        self.returns[-1] = next_value
        for ad_step in reversed(range(self.rewards.size(0))):
            # advantage 고려 Q함수의 수정
            self.returns[ad_step] = self.returns[ad_step + 1] * GAMMA * self.masks[ad_step + 1] + self.rewards[ad_step]

# %%
class Net(nn.Module):
    def __init__(self, n_in: int, n_mid: int, n_out: int) -> None:
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in,n_mid)
        self.fc2 = nn.Linear(n_mid,n_mid)
        self.actor = nn.Linear(n_mid, n_out)        # Actor net(8 action output)
        self.critic = nn.Linear(n_mid, 1)           # critic net (state value -> 1)
    
    def forward(self, x) -> list:
        '''Forward wave 계산을 정의'''
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        critic_output = self.critic(h2)
        actor_output = self.actor(h2)

        return critic_output, actor_output
    
    def act(self, x):
        '''상태 x로부터 행동을 확률적으로 결정'''
        value, actor_output = self(x)
        action_probs = F.softmax(actor_output, dim=1)       # softmax 를 통한 행동의 확률 계산
        action = action_probs.multinomial(num_samples=1)
        return action

    def get_value(self, x):
        '''상태 x로부터 상태가치를 계산'''
        value, actor_output = self(x)

        return value
    
    def evaluate_actions(self, x, actions) -> list:
        '''상태 x로부터 상태가치, 실제 행동 actions의 로그 확률, 엔트로피를 계산'''
        value, actor_output = self(x)

        log_probs = F.log_softmax(actor_output, dim=1)      # dim=1이므로 행동의 종류에 대해 확률을 계산
        action_log_probs = log_probs.gather(1, actions)    # 실제 행동의 로그 확률(log_probs)을 구함

        probs = F.softmax(actor_output, dim=1)
        entropy = -(log_probs * probs).sum(-1).mean()

        return value, action_log_probs, entropy

# %%
class Brain(object):
    def __init__(self, actor_critic: Net) -> None:
        self.actor_critic = actor_critic
        self.optimizer = optim.Adam(self.actor_critic.parameters(), lr=0.01)    # learning rate = 0.01 (faster)
        
    def update(self, rollouts: RolloutStorage) -> None:
        ''''Advantage학습의 대상이 되는 5단계 모두를 사용하여 수정'''
        obs_shape = rollouts.observations.size()[2:]    # torch.Size([12])
        num_steps = NUM_ADVANCED_STEP
        num_processes = NUM_PROCESSES

        values, action_log_probs, entropy = self.actor_critic.evaluate_actions(
            rollouts.observations[:-1].view(-1,12),
            rollouts.actions.view(-1,1)
        )

        # 주의 : 각 변수의 크기
        # rollouts.observations[:-1].view(-1, 4) torch.Size([192, 12])
        # rollouts.actions.view(-1, 1) torch.Size([192, 8])
        # values torch.Size([80, 1])
        # action_log_probs torch.Size([80, 1])
        # entropy torch.Size([])

        values = values.view(num_steps, num_processes, 1)   # torch.Size([5, 32, 1])
        action_log_probs = action_log_probs.view(num_steps, num_processes, 1)

        # advantage(행동가치-상태가치) 계산
        advantages = rollouts.returns[:-1] - values          # torch.Size([6, 32, 1])

        # Critic loss 계산
        value_loss = advantages.pow(2).mean()

        # Actor의 gain 계산, 나중에 -1을 곱하면 loss가 된다
        action_gain = (action_log_probs * advantages.detach()).mean()
        # detach 메서드를 호출하여 advantages를 상수로 취급

        # 오차함수의 총합
        total_loss = (value_loss * VALUE_LOSS_COEFF - action_gain - entropy * ENTROPY_COEFF)
        
        # 가중치 수정
        self.actor_critic.train()
        self.optimizer.zero_grad()
        total_loss.backward()
        # 결합 가중치가 한번에 너무 크게 변화하지 않도록, 경사를 0.5 이하로 제한함(클리핑)
        nn.utils.clip_grad_norm_(self.actor_critic.parameters(), MAX_GRAD_NORM)

        self.optimizer.step()

# %%
class Environment:
    def run(self) -> None:
        '''running entry point'''
        # 동시 실행할 환경 수 만큼 env를 생성
        space_lim = [500, 500, 500]
        envs = [QuadRotorEnv(space_lim) for i in range(NUM_PROCESSES)]

        # 모든 에이전트가 공유하는 Brain 객체를 생성
        n_in = envs[0].observation_space_size           # state inputs
        n_out = envs[0].action_space_size               # action outpus
        n_mid = 96                                      # 48 mid junction
        actor_critic = Net(n_in, n_mid, n_out).to(device)          # Net init
        glob_brain = Brain(actor_critic)                # Brain init

        # 각종 정보를 저장하는 변수
        l_arm = 0.3                             # length or the rotor arm [m]
        m = 1.3                                 # mass of vehicle [kg]
        rho = 1.225                             # density of air [kg/m^3]
        r = 0.1                                 # radius of propeller
        V = 11.1                                # voltage of battery [V]
        kV = 1550                               # motor kV constant, [rpm/V]
        CT = 1.0e-2                             # Thrust coeff
        Cm = 1e-4                               # moment coeff
        g = 9.81                                # gravitational constant [m/s^2]
        Jx = 0.021                              # Moment of inertia Ixx [kg*m^2]
        Jy = 0.021                              # Moment of inertia Iyy [kg*m^2]
        Jz = 0.042                              # Moment of inertia Izz [kg*m^2]
        p = [m, l_arm, r, rho, V, kV, CT, Cm, g, Jx, Jy, Jz]
        obs_shape = n_in
        current_obs = torch.zeros(NUM_PROCESSES, obs_shape).to(device)                         # (16,4) 의 tensor
        rollouts = RolloutStorage(NUM_ADVANCED_STEP, NUM_PROCESSES,obs_shape)       # RolloutStorage init
        episode_rewards = torch.zeros(NUM_PROCESSES, 1)                             # 현재 episode 의 reward
        final_rewards = torch.zeros(NUM_PROCESSES, 1)                               # 마지막 episode 의 reward
        obs_np = np.zeros([NUM_PROCESSES, obs_shape])                               # state 배열
        reward_np = np.zeros([NUM_PROCESSES, 1])                                    # 보상의 배열
        done_np = np.zeros([NUM_PROCESSES, 1])                                      # Done 여부의 배열
        arrive_np = np.zeros([NUM_PROCESSES, 1])                                    # Arrive 여부의 배열
        arrive_time = []                                                            # Arrive time 의 저장 버퍼
        distance_np = np.zeros([NUM_PROCESSES, 1])                                  # check distance array
        each_step = np.zeros(NUM_PROCESSES)                                         # 각 env 의 step record
        episode = 0
        # 초기 state...
        obs = [envs[i].reset(p) for i in range(NUM_PROCESSES)]
        obs = np.array(obs)
        obs = torch.from_numpy(obs).float()                     # (32,12) 의 tensor
        current_obs = obs                                       # current obs 의 업데이트

        # advanced 학습(action actor)에 사용되는 객체 rollouts 첫번째 상태에 현재 상태를 저장
        rollouts.observations[0].copy_(current_obs)

        # 에피소드 반복문
        for episode in range(NUM_PROCESSES * NUM_EPISODES):
            # advanced 학습(action actor) 대상이 되는 각 단계에 대해 계산 (step 반복)
            for step in range(NUM_ADVANCED_STEP):
                # action 을 fetch
                with torch.no_grad():
                    action = actor_critic.act(rollouts.observations[step])
                # (16,1)→(16,) -> tensor를 NumPy변수로
                actions = action.squeeze(1).cpu().numpy()

                # process 반복
                for i in range(NUM_PROCESSES):
                    obs_np[i], reward_np[i], done_np[i], arrive_np[i], distance_np[i]\
                       = envs[i].step(actions[i], each_step[i])

                    # episode의 종료가치, state_next를 설정
                    if done_np[i]:          # success or fail
                        print(f'{episode} set, {i} slot: {(each_step[i] + 1)/100} [s]')
                        episode += 1
                        if arrive_np[i]:    # done with arrival
                            reward_np[i] = 20
                            print('arrived!')
                            #if len(arrive_time) == 0:   # First arrival
                            #    reward_np[i] = 20.0
                            #    arrive_time.append(each_step[i] / 100)
                            #else:
                            #    for j in arrive_time:
                            #        if j > (each_step[i] / 100):    # better record of success
                            #            arrive_time.append(each_step[i] / 100)
                            #            reward_np[i] = 20.0
                            #        else:                           # poor or same performace to last success (probably not needed because of gamma)
                            #            reward_np[i] = 0.0
                        else:
                            if distance_np[i] <= 10:
                                reward_np[i] = 0.1
                            else:
                                reward_np[i] = -10.0
                        each_step[i] = 0.0            # step 초기화
                        obs_np[i] = envs[i].reset(p) # 환경 초기화
                    else:                           # 무너지거나 성공도 아님
                        reward_np[i] = 0.0
                        each_step[i] += 1           # 그대로 진행

                # 보상을 tensor로 변환하고, 에피소드의 총보상에 더해줌
                reward = torch.from_numpy(reward_np).float()
                episode_rewards += reward

                # 각 실행 환경을 확인하여 done이 true이면 mask를 0으로, false이면 mask를 1로
                masks = torch.FloatTensor([[0.0] if done_i else [1.0] for done_i in done_np])

                # 마지막 에피소드의 총 보상을 업데이트
                final_rewards *= masks      # done이 false이면 1을 곱하고, true이면 0을 곱해 초기화
                # done이 false이면 0을 더하고, true이면 episode_rewards를 더해줌
                final_rewards += (1 - masks)*episode_rewards

                # 에피소드의 총보상을 업데이트
                episode_rewards *= masks

                # 현재 done이 true이면 모두 0으로 
                current_obs *= masks

                # current_obs를 업데이트
                obs = torch.from_numpy(obs_np).float()  # torch.Size([32, 12])
                current_obs = obs  # 최신 상태의 obs를 저장

                # 메모리 객체에 현 단계의 transition을 저장
                rollouts.insert(current_obs, action.data, reward, masks)

            # advanced 학습 for문 끝

            # advanced 학습 대상 중 마지막 단계의 상태로 예측하는 상태가치를 계산

            with torch.no_grad():
                next_value = actor_critic.get_value(rollouts.observations[-1]).detach()
                # next_value는 다음 state의 상태가치
                # rollouts.observations의 크기는 torch.Size([6, 16, 4])
            
            # 모든 단계의 할인총보상을 계산하고, rollouts의 변수 returns를 업데이트
            rollouts.compute_returns(next_value)

            # 신경망 및 rollout 업데이트
            glob_brain.update(rollouts)
            rollouts.after_update()

            # 모든 환경이 성공(도착)
            if final_rewards.sum().numpy() >= NUM_PROCESSES*20:
                print('모든 환경 성공')
                break

# %%
if __name__ == '__main__':
    cartpole_env = Environment()
    cartpole_env.run()
# Out:
# crashed to ground
# 2 set, 2 slot: 1.01 [s]
# crashed to ground
# 3 set, 4 slot: 1.01 [s]
# crashed to ground
# 4 set, 6 slot: 1.01 [s]
# crashed to ground
# 5 set, 9 slot: 1.01 [s]
# crashed to ground
# 6 set, 11 slot: 1.01 [s]
# crashed to ground
# 7 set, 14 slot: 1.01 [s]
# crashed to ground
# 8 set, 16 slot: 1.01 [s]
# crashed to ground
# 9 set, 23 slot: 1.01 [s]
# crashed to ground
# 10 set, 24 slot: 1.01 [s]
# crashed to ground
# 11 set, 30 slot: 1.01 [s]
# crashed to ground
# 12 set, 31 slot: 1.01 [s]
# crashed to ground
# 13 set, 19 slot: 1.04 [s]
# crashed to ground
# 14 set, 28 slot: 1.09 [s]
# crashed to ground
# 15 set, 8 slot: 1.34 [s]
# crashed to ground
# 3 set, 3 slot: 1.57 [s]
# crashed to ground
# 4 set, 20 slot: 1.64 [s]
# crashed to ground
# 4 set, 9 slot: 1.01 [s]
# crashed to ground
# 5 set, 11 slot: 1.01 [s]
# crashed to ground
# 6 set, 23 slot: 1.01 [s]
# crashed to ground
# 7 set, 24 slot: 1.01 [s]
# crashed to ground
# 8 set, 19 slot: 1.01 [s]
# crashed to ground
# 9 set, 27 slot: 2.21 [s]
# crashed to ground
# 10 set, 30 slot: 1.25 [s]
# crashed to ground
# 11 set, 25 slot: 2.34 [s]
# crashed to ground
# 12 set, 15 slot: 2.39 [s]
# crashed to ground
# 5 set, 20 slot: 1.01 [s]
# crashed to ground
# 6 set, 21 slot: 2.71 [s]
# crashed to ground
# 7 set, 12 slot: 2.8 [s]
# crashed to ground
# 8 set, 10 slot: 2.84 [s]
# crashed to ground
# 6 set, 11 slot: 1.01 [s]
# crashed to ground
# 7 set, 23 slot: 1.01 [s]
# crashed to ground
# 8 set, 28 slot: 2.08 [s]
# crashed to ground
# 9 set, 18 slot: 3.35 [s]
# crashed to ground
# 10 set, 25 slot: 1.01 [s]
# crashed to ground
# 7 set, 31 slot: 2.56 [s]
# crashed to ground
# 8 set, 13 slot: 3.59 [s]
# crashed to ground
# 9 set, 1 slot: 3.63 [s]
# crashed to ground
# 10 set, 21 slot: 1.01 [s]
# crashed to ground
# 11 set, 10 slot: 1.01 [s]
# crashed to ground
# 12 set, 26 slot: 3.87 [s]
# crashed to ground
# 8 set, 11 slot: 1.01 [s]
# crashed to ground
# 9 set, 5 slot: 4.23 [s]
# crashed to ground
# 10 set, 29 slot: 4.26 [s]
# crashed to ground
# 11 set, 16 slot: 3.38 [s]
# crashed to ground
# 12 set, 9 slot: 2.38 [s]
# crashed to ground
# 9 set, 22 slot: 4.52 [s]
# crashed to ground
# 10 set, 31 slot: 1.01 [s]
# crashed to ground
# 11 set, 13 slot: 1.01 [s]
# crashed to ground
# 12 set, 21 slot: 1.01 [s]
# crashed to ground
# 13 set, 10 slot: 1.01 [s]
# crashed to ground
# 14 set, 7 slot: 4.92 [s]
# crashed to ground
# 10 set, 0 slot: 5.06 [s]
# over the limit!
# 11 set, 2 slot: 4.13 [s]
# crashed to ground
# 12 set, 5 slot: 1.01 [s]
# over the limit!
# 13 set, 8 slot: 3.98 [s]
# crashed to ground
# 14 set, 1 slot: 1.75 [s]
# crashed to ground
# 15 set, 9 slot: 1.01 [s]
# crashed to ground
# 11 set, 13 slot: 1.01 [s]
# over the limit!
# 12 set, 19 slot: 3.66 [s]
# over the limit!
# 13 set, 6 slot: 4.76 [s]
# over the limit!
# 14 set, 20 slot: 3.25 [s]
# crashed to ground
# 12 set, 2 slot: 1.01 [s]
# over the limit!
# 13 set, 12 slot: 3.42 [s]
# over the limit!
# 14 set, 3 slot: 4.69 [s]
# over the limit!
# 15 set, 24 slot: 4.25 [s]
# over the limit!
# 16 set, 27 slot: 4.13 [s]
# over the limit!
# 17 set, 30 slot: 4.18 [s]
# over the limit!
# 13 set, 15 slot: 4.22 [s]
# over the limit!
# 14 set, 18 slot: 3.3 [s]
# over the limit!
# 15 set, 23 slot: 3.64 [s]
# over the limit!
# 16 set, 14 slot: 5.74 [s]
# over the limit!
# 14 set, 4 slot: 6.01 [s]
# over the limit!
# 15 set, 25 slot: 3.74 [s]
# over the limit!
# 16 set, 17 slot: 7.14 [s]
# over the limit!
# 17 set, 11 slot: 3.29 [s]
# over the limit!
# 15 set, 29 slot: 3.41 [s]
# over the limit!
# 16 set, 28 slot: 4.8 [s]
# over the limit!
# 16 set, 16 slot: 3.74 [s]
# over the limit!
# 17 set, 7 slot: 3.29 [s]
# over the limit!
# 18 set, 22 slot: 3.8 [s]
# over the limit!
# 19 set, 0 slot: 3.37 [s]
# over the limit!
# 17 set, 10 slot: 3.65 [s]
# over the limit!
# 18 set, 26 slot: 4.64 [s]
# over the limit!
# 19 set, 31 slot: 3.93 [s]
# over the limit!
# 20 set, 8 slot: 3.28 [s]
# over the limit!
# 21 set, 13 slot: 3.24 [s]
# over the limit!
# 22 set, 9 slot: 3.46 [s]
# over the limit!
# 23 set, 21 slot: 4.26 [s]
# over the limit!
# 18 set, 1 slot: 3.77 [s]
# over the limit!
# 19 set, 6 slot: 3.39 [s]
# over the limit!
# 20 set, 19 slot: 3.67 [s]
# over the limit!
# 21 set, 5 slot: 4.25 [s]
# over the limit!
# 19 set, 12 slot: 3.48 [s]
# over the limit!
# 20 set, 24 slot: 3.46 [s]
# over the limit!
# 20 set, 2 slot: 3.87 [s]
# over the limit!
# 21 set, 14 slot: 3.27 [s]
# over the limit!
# 22 set, 3 slot: 3.81 [s]
# over the limit!
# 23 set, 18 slot: 3.42 [s]
# over the limit!
# 24 set, 30 slot: 3.65 [s]
# over the limit!
# 25 set, 20 slot: 4.23 [s]
# over the limit!
# 26 set, 15 slot: 3.53 [s]
# over the limit!
# 27 set, 27 slot: 4.05 [s]
# over the limit!
# 28 set, 23 slot: 3.82 [s]
# over the limit!
# 21 set, 25 slot: 3.43 [s]
# over the limit!
# 22 set, 4 slot: 3.63 [s]
# over the limit!
# 23 set, 11 slot: 3.53 [s]
# over the limit!
# 24 set, 17 slot: 3.72 [s]
# over the limit!
# 25 set, 29 slot: 3.33 [s]
# over the limit!
# 23 set, 7 slot: 3.34 [s]
# over the limit!
# 24 set, 22 slot: 3.29 [s]
# over the limit!
# 25 set, 0 slot: 3.24 [s]
# over the limit!
# 26 set, 16 slot: 3.56 [s]
# over the limit!
# 27 set, 28 slot: 3.72 [s]
# over the limit!
# 28 set, 8 slot: 3.24 [s]
# over the limit!
# 24 set, 21 slot: 3.22 [s]
# over the limit!
# 25 set, 31 slot: 3.82 [s]
# over the limit!
# 26 set, 9 slot: 3.5 [s]
# over the limit!
# 27 set, 1 slot: 3.26 [s]
# over the limit!
# 25 set, 6 slot: 3.37 [s]
# over the limit!
# 26 set, 13 slot: 3.71 [s]
# over the limit!
# 27 set, 19 slot: 3.3 [s]
# over the limit!
# 28 set, 26 slot: 4.21 [s]
# over the limit!
# 29 set, 10 slot: 4.32 [s]
# over the limit!
# 30 set, 5 slot: 3.51 [s]
# over the limit!
# 26 set, 24 slot: 3.36 [s]
# over the limit!
# 27 set, 14 slot: 3.35 [s]
# over the limit!
# 28 set, 2 slot: 3.37 [s]
# over the limit!
# 27 set, 20 slot: 3.49 [s]
# over the limit!
# 28 set, 12 slot: 3.98 [s]
# over the limit!
# 29 set, 27 slot: 3.35 [s]
# over the limit!
# 30 set, 18 slot: 3.69 [s]
# over the limit!
# 31 set, 15 slot: 3.65 [s]
# over the limit!
# 32 set, 25 slot: 3.4 [s]
# crashed to ground
# 28 set, 19 slot: 1.48 [s]
# over the limit!
# 29 set, 23 slot: 3.87 [s]
# crashed to ground
# 30 set, 2 slot: 1.01 [s]
# over the limit!
# 29 set, 30 slot: 4.67 [s]
# over the limit!
# 31 set, 8 slot: 3.68 [s]
# over the limit!
# 32 set, 4 slot: 4.97 [s]
# over the limit!
# 32 set, 17 slot: 5.31 [s]
# over the limit!
# 33 set, 11 slot: 5.57 [s]
# over the limit!
# 33 set, 31 slot: 4.66 [s]
# over the limit!
# 34 set, 6 slot: 4.62 [s]
# over the limit!
# 35 set, 0 slot: 5.63 [s]
# over the limit!
# 36 set, 27 slot: 3.66 [s]
# over the limit!
# 37 set, 1 slot: 5.0 [s]
# crashed to ground
# 38 set, 11 slot: 1.01 [s]
# crashed to ground
# 35 set, 22 slot: 5.92 [s]
# over the limit!
# 36 set, 14 slot: 4.24 [s]
# over the limit!
# 37 set, 10 slot: 4.79 [s]
# over the limit!
# 38 set, 2 slot: 3.47 [s]
# over the limit!
# 36 set, 30 slot: 3.3 [s]
# over the limit!
# 37 set, 25 slot: 4.22 [s]
# over the limit!
# 38 set, 16 slot: 6.53 [s]
# over the limit!
# 39 set, 3 slot: 8.17 [s]
# over the limit!
# 40 set, 15 slot: 4.61 [s]
# crashed to ground
# 37 set, 22 slot: 1.01 [s]
# over the limit!
# 38 set, 13 slot: 6.03 [s]
# crashed to ground
# 39 set, 14 slot: 1.01 [s]
# over the limit!
# 40 set, 18 slot: 4.97 [s]
# over the limit!
# 41 set, 24 slot: 5.8 [s]
# over the limit!
# 42 set, 12 slot: 5.22 [s]
# crashed to ground
# 43 set, 21 slot: 6.69 [s]
# over the limit!
# 38 set, 5 slot: 6.02 [s]
# over the limit!
# 39 set, 29 slot: 8.21 [s]
# over the limit!
# 39 set, 20 slot: 5.92 [s]
# crashed to ground
# 40 set, 9 slot: 7.6 [s]
# over the limit!
# 40 set, 8 slot: 4.51 [s]
# crashed to ground
# 41 set, 21 slot: 1.15 [s]
# crashed to ground
# 42 set, 7 slot: 8.85 [s]
# over the limit!
# 41 set, 17 slot: 4.45 [s]
# over the limit!
# 42 set, 6 slot: 3.7 [s]
# crashed to ground
# 43 set, 28 slot: 9.16 [s]
# over the limit!
# 44 set, 0 slot: 3.69 [s]
# over the limit!
# 45 set, 26 slot: 8.28 [s]
# crashed to ground
# 42 set, 2 slot: 3.15 [s]
# crashed to ground
# 43 set, 8 slot: 1.01 [s]
# over the limit!
# 44 set, 4 slot: 5.53 [s]
# over the limit!
# 45 set, 1 slot: 3.83 [s]
# over the limit!
# 43 set, 16 slot: 3.49 [s]
# over the limit!
# 44 set, 27 slot: 4.35 [s]
# over the limit!
# 45 set, 22 slot: 3.44 [s]
# crashed to ground
# 46 set, 0 slot: 1.01 [s]
# crashed to ground
# 44 set, 2 slot: 1.01 [s]
# over the limit!
# 45 set, 3 slot: 3.84 [s]
# over the limit!
# 46 set, 19 slot: 7.92 [s]
# over the limit!
# 47 set, 24 slot: 3.47 [s]
# crashed to ground
# 48 set, 1 slot: 1.24 [s]
# over the limit!
# 45 set, 14 slot: 3.92 [s]
# over the limit!
# 46 set, 11 slot: 5.14 [s]
# over the limit!
# 47 set, 18 slot: 3.91 [s]
# crashed to ground
# 48 set, 23 slot: 8.45 [s]
# over the limit!
# 49 set, 30 slot: 4.82 [s]
# over the limit!
# 50 set, 25 slot: 4.77 [s]
# crashed to ground
# 47 set, 14 slot: 1.01 [s]
# over the limit!
# 48 set, 5 slot: 4.61 [s]
# over the limit!
# 49 set, 7 slot: 3.31 [s]
# crashed to ground
# 48 set, 31 slot: 7.05 [s]
# over the limit!
# 49 set, 6 slot: 3.28 [s]
# over the limit!
# 50 set, 29 slot: 5.22 [s]
# crashed to ground
# 49 set, 21 slot: 4.67 [s]
# over the limit!
# 50 set, 12 slot: 6.11 [s]
# crashed to ground
# 51 set, 15 slot: 6.84 [s]
# crashed to ground
# 51 set, 21 slot: 1.03 [s]
# over the limit!
# 52 set, 20 slot: 6.85 [s]
# crashed to ground
# 53 set, 8 slot: 5.38 [s]
# crashed to ground
# 54 set, 28 slot: 5.64 [s]
# crashed to ground
# 55 set, 31 slot: 2.46 [s]
# over the limit!
# 53 set, 19 slot: 4.53 [s]
# over the limit!
# 54 set, 30 slot: 3.93 [s]
# over the limit!
# 54 set, 4 slot: 6.04 [s]
# over the limit!
# 55 set, 22 slot: 5.24 [s]
# over the limit!
# 56 set, 16 slot: 5.55 [s]
# crashed to ground
# 57 set, 20 slot: 1.01 [s]
# crashed to ground
# 55 set, 9 slot: 7.76 [s]
# crashed to ground
# 56 set, 18 slot: 5.21 [s]
# crashed to ground
# 57 set, 30 slot: 1.08 [s]
# crashed to ground
# 58 set, 26 slot: 6.96 [s]
# over the limit!
# 56 set, 2 slot: 5.99 [s]
# crashed to ground
# 57 set, 17 slot: 7.48 [s]
# over the limit!
# 58 set, 11 slot: 5.6 [s]
# over the limit!
# 59 set, 24 slot: 5.84 [s]
# crashed to ground
# 60 set, 25 slot: 5.35 [s]
# over the limit!
# 61 set, 10 slot: 10.68 [s]
# crashed to ground
# 62 set, 6 slot: 4.18 [s]
# over the limit!
# 57 set, 13 slot: 10.25 [s]
# over the limit!
# 58 set, 29 slot: 4.43 [s]
# over the limit!
# 59 set, 0 slot: 6.87 [s]
# crashed to ground
# 60 set, 30 slot: 1.01 [s]
# crashed to ground
# 61 set, 23 slot: 6.14 [s]
# crashed to ground
# 58 set, 25 slot: 1.01 [s]
# over the limit!
# 59 set, 7 slot: 5.89 [s]
# over the limit!
# 60 set, 27 slot: 7.89 [s]
# over the limit!
# 60 set, 12 slot: 5.02 [s]
# over the limit!
# 61 set, 3 slot: 8.1 [s]
# over the limit!
# 61 set, 5 slot: 6.88 [s]
# crashed to ground
# 62 set, 1 slot: 8.12 [s]
# over the limit!
# 63 set, 15 slot: 5.42 [s]
# over the limit!
# 64 set, 28 slot: 4.28 [s]
# over the limit!
# 62 set, 31 slot: 4.58 [s]
# over the limit!
# 63 set, 19 slot: 4.58 [s]
# over the limit!
# 64 set, 4 slot: 4.18 [s]
# over the limit!
# 65 set, 16 slot: 4.19 [s]
# over the limit!
# 63 set, 20 slot: 4.15 [s]
# over the limit!
# 64 set, 26 slot: 3.65 [s]
# over the limit!
# 65 set, 2 slot: 3.61 [s]
# over the limit!
# 64 set, 17 slot: 4.12 [s]
# over the limit!
# 65 set, 8 slot: 5.96 [s]
# over the limit!
# 66 set, 22 slot: 5.16 [s]
# over the limit!
# 67 set, 11 slot: 4.24 [s]
# over the limit!
# 65 set, 24 slot: 4.35 [s]
# over the limit!
# over the limit!
# 66 set, 14 slot: 9.13 [s]
# over the limit!
# 67 set, 25 slot: 3.43 [s]
# over the limit!
# 68 set, 23 slot: 3.86 [s]
# over the limit!
# 69 set, 21 slot: 7.18 [s]
# over the limit!
# 70 set, 6 slot: 4.68 [s]
# over the limit!
# 66 set, 30 slot: 4.15 [s]
# over the limit!
# 67 set, 7 slot: 3.64 [s]
# over the limit!
# 68 set, 12 slot: 3.26 [s]
# over the limit!
# 69 set, 10 slot: 5.0 [s]
# over the limit!
# 70 set, 9 slot: 5.63 [s]
# crashed to ground
# 71 set, 22 slot: 1.01 [s]
# over the limit!
# 67 set, 29 slot: 4.71 [s]
# over the limit!
# 68 set, 3 slot: 3.63 [s]
# over the limit!
# 69 set, 13 slot: 5.02 [s]
# crashed to ground
# 70 set, 21 slot: 1.01 [s]
# over the limit!
# 68 set, 5 slot: 3.79 [s]
# crashed to ground
# 69 set, 31 slot: 3.22 [s]
# crashed to ground
# 70 set, 22 slot: 1.01 [s]
# over the limit!
# 69 set, 4 slot: 3.26 [s]
# over the limit!
# 70 set, 18 slot: 6.93 [s]
# crashed to ground
# 71 set, 3 slot: 1.01 [s]
# over the limit!
# 72 set, 1 slot: 4.28 [s]
# over the limit!
# 70 set, 0 slot: 6.15 [s]
# over the limit!
# 71 set, 19 slot: 3.9 [s]
# over the limit!
# 72 set, 16 slot: 3.68 [s]
# over the limit!
# 73 set, 15 slot: 4.59 [s]
# over the limit!
# 74 set, 28 slot: 4.5 [s]
# crashed to ground
# 75 set, 31 slot: 1.01 [s]
# over the limit!
# 76 set, 2 slot: 3.7 [s]
# over the limit!
# 77 set, 27 slot: 5.83 [s]
# over the limit!
# 71 set, 20 slot: 4.33 [s]
# over the limit!
# 72 set, 25 slot: 3.35 [s]
# over the limit!
# 73 set, 23 slot: 3.4 [s]
# crashed to ground
# 74 set, 15 slot: 1.01 [s]
# crashed to ground
# 75 set, 31 slot: 1.01 [s]
# over the limit!
# 73 set, 12 slot: 3.32 [s]
# over the limit!
# 74 set, 26 slot: 5.14 [s]
# crashed to ground
# 75 set, 27 slot: 1.31 [s]
# over the limit!
# 76 set, 11 slot: 4.57 [s]
# over the limit!
# 74 set, 24 slot: 4.49 [s]
# over the limit!
# 75 set, 8 slot: 4.82 [s]
# over the limit!
# 76 set, 6 slot: 4.23 [s]
# crashed to ground
# 77 set, 23 slot: 1.01 [s]
# crashed to ground
# 78 set, 31 slot: 1.01 [s]
# over the limit!
# 79 set, 13 slot: 3.48 [s]
# crashed to ground
# 75 set, 15 slot: 1.31 [s]
# crashed to ground
# 76 set, 26 slot: 1.01 [s]
# over the limit!
# 76 set, 14 slot: 5.36 [s]
# over the limit!
# 77 set, 17 slot: 5.86 [s]
# over the limit!
# 78 set, 9 slot: 4.79 [s]
# over the limit!
# 79 set, 30 slot: 5.17 [s]
# crashed to ground
# 80 set, 6 slot: 1.01 [s]
# crashed to ground
# 81 set, 27 slot: 1.53 [s]
# over the limit!
# 82 set, 16 slot: 3.22 [s]
# over the limit!
# 83 set, 1 slot: 3.51 [s]
# over the limit!
# 84 set, 22 slot: 4.01 [s]
# over the limit!
# 85 set, 21 slot: 4.5 [s]
# over the limit!
# 86 set, 18 slot: 3.71 [s]
# over the limit!
# 77 set, 10 slot: 5.43 [s]
# crashed to ground
# 78 set, 31 slot: 1.43 [s]
# over the limit!
# 79 set, 4 slot: 4.24 [s]
# over the limit!
# 80 set, 3 slot: 4.06 [s]
# over the limit!
# 81 set, 29 slot: 5.39 [s]
# over the limit!
# 78 set, 5 slot: 4.72 [s]
# crashed to ground
# 79 set, 11 slot: 2.16 [s]
# over the limit!
# 80 set, 19 slot: 4.21 [s]
# over the limit!
# 81 set, 28 slot: 4.05 [s]
# crashed to ground
# 82 set, 16 slot: 1.01 [s]
# crashed to ground
# 83 set, 30 slot: 1.2 [s]
# crashed to ground
# 84 set, 27 slot: 1.19 [s]
# over the limit!
# 79 set, 20 slot: 3.64 [s]
# crashed to obstacle
# 80 set, 2 slot: 4.29 [s]
# over the limit!
# 81 set, 0 slot: 4.63 [s]
# over the limit!
# 82 set, 7 slot: 6.69 [s]
# over the limit!
# 80 set, 25 slot: 3.99 [s]
# crashed to ground
# 81 set, 8 slot: 2.91 [s]
# over the limit!
# 82 set, 15 slot: 2.92 [s]
# crashed to ground
# 82 set, 25 slot: 1.01 [s]
# over the limit!
# 83 set, 12 slot: 4.59 [s]
# crashed to ground
# 84 set, 29 slot: 2.26 [s]
# over the limit!
# 85 set, 13 slot: 3.89 [s]
# crashed to ground
# 86 set, 8 slot: 1.18 [s]
# over the limit!
# 87 set, 23 slot: 4.1 [s]
# over the limit!
# 88 set, 14 slot: 3.35 [s]
# over the limit!
# 83 set, 9 slot: 3.36 [s]
# crashed to ground
# 84 set, 19 slot: 2.31 [s]
# over the limit!
# 85 set, 1 slot: 3.54 [s]
# over the limit!
# 84 set, 17 slot: 3.97 [s]
# crashed to ground
# 85 set, 21 slot: 3.9 [s]
# over the limit!
# 85 set, 4 slot: 3.65 [s]
# crashed to ground
# 86 set, 9 slot: 1.01 [s]
# over the limit!
# 87 set, 24 slot: 5.49 [s]
# over the limit!
# 88 set, 18 slot: 4.05 [s]
# crashed to ground
# 89 set, 20 slot: 3.02 [s]
# over the limit!
# 90 set, 22 slot: 4.25 [s]
# over the limit!
# 91 set, 31 slot: 3.94 [s]
# over the limit!
# 92 set, 5 slot: 3.69 [s]
# over the limit!
# 93 set, 26 slot: 5.08 [s]
# over the limit!
# 86 set, 3 slot: 4.25 [s]
# over the limit!
# 87 set, 28 slot: 3.86 [s]
# over the limit!
# 88 set, 6 slot: 5.06 [s]
# over the limit!
# 89 set, 30 slot: 3.9 [s]
# over the limit!
# 90 set, 10 slot: 4.66 [s]
# crashed to ground
# 91 set, 16 slot: 4.06 [s]
# over the limit!
# 87 set, 7 slot: 3.6 [s]
# crashed to ground
# 88 set, 20 slot: 1.01 [s]
# over the limit!
# 89 set, 11 slot: 4.52 [s]
# over the limit!
# 88 set, 27 slot: 4.52 [s]
# over the limit!
# 89 set, 2 slot: 4.63 [s]
# crashed to ground
# 90 set, 6 slot: 1.01 [s]
# over the limit!
# 91 set, 0 slot: 4.83 [s]
# over the limit!
# 92 set, 15 slot: 4.0 [s]
# over the limit!
# 90 set, 1 slot: 3.09 [s]
# over the limit!
# 91 set, 8 slot: 3.79 [s]
# over the limit!
# 92 set, 29 slot: 3.92 [s]
# over the limit!
# 93 set, 19 slot: 3.66 [s]
# over the limit!
# 91 set, 23 slot: 4.45 [s]
# over the limit!
# 92 set, 25 slot: 4.76 [s]
# over the limit!
# 93 set, 14 slot: 4.51 [s]
# over the limit!
# 92 set, 13 slot: 4.84 [s]
# over the limit!
# 93 set, 31 slot: 3.38 [s]
# over the limit!
# 94 set, 9 slot: 3.59 [s]
# over the limit!
# 95 set, 4 slot: 3.8 [s]
# over the limit!
# 96 set, 24 slot: 3.81 [s]
# over the limit!
# 97 set, 5 slot: 3.64 [s]
# over the limit!
# 98 set, 18 slot: 3.89 [s]
# over the limit!
# 99 set, 17 slot: 4.4 [s]
# over the limit!
# 93 set, 3 slot: 3.57 [s]
# over the limit!
# 94 set, 22 slot: 4.04 [s]
# over the limit!
# 95 set, 10 slot: 3.37 [s]
# over the limit!
# 96 set, 12 slot: 5.63 [s]
# over the limit!
# 97 set, 16 slot: 3.5 [s]
# over the limit!
# 98 set, 28 slot: 3.78 [s]
# over the limit!
# 94 set, 26 slot: 4.18 [s]
# over the limit!
# 95 set, 30 slot: 3.8 [s]
# over the limit!
# 96 set, 7 slot: 3.96 [s]
# over the limit!
# 95 set, 21 slot: 5.17 [s]
# over the limit!
# 96 set, 2 slot: 3.31 [s]
# over the limit!
# 97 set, 27 slot: 3.56 [s]
# over the limit!
# 98 set, 6 slot: 3.33 [s]
# over the limit!
# 99 set, 20 slot: 4.11 [s]
# over the limit!
# 100 set, 11 slot: 4.07 [s]
# over the limit!
# 96 set, 0 slot: 3.76 [s]
# over the limit!
# 97 set, 15 slot: 3.83 [s]
# over the limit!
# 98 set, 1 slot: 4.09 [s]
# over the limit!
# 99 set, 29 slot: 4.12 [s]
# over the limit!
# 100 set, 25 slot: 3.49 [s]
# over the limit!
# 101 set, 19 slot: 4.21 [s]
# over the limit!
# 99 set, 8 slot: 4.5 [s]
# over the limit!
# 100 set, 24 slot: 3.28 [s]
# over the limit!
# 101 set, 5 slot: 3.36 [s]
# over the limit!
# 102 set, 13 slot: 3.71 [s]
# over the limit!
# 103 set, 9 slot: 3.81 [s]
# over the limit!
# 104 set, 23 slot: 4.17 [s]
# over the limit!
# 100 set, 17 slot: 3.6 [s]
# over the limit!
# 101 set, 31 slot: 4.11 [s]
# over the limit!
# 102 set, 16 slot: 3.29 [s]
# over the limit!
# 103 set, 12 slot: 3.48 [s]
# over the limit!
# over the limit!
# 104 set, 14 slot: 4.48 [s]
# over the limit!
# 105 set, 26 slot: 3.36 [s]
# over the limit!
# 106 set, 22 slot: 3.75 [s]
# over the limit!
# 107 set, 10 slot: 3.7 [s]
# over the limit!
# 108 set, 4 slot: 4.16 [s]
# over the limit!
# 101 set, 18 slot: 4.37 [s]
# over the limit!
# 102 set, 20 slot: 3.24 [s]
# over the limit!
# 103 set, 3 slot: 4.21 [s]
# over the limit!
# 102 set, 27 slot: 3.51 [s]
# over the limit!
# 103 set, 28 slot: 4.19 [s]
# over the limit!
# 104 set, 7 slot: 3.67 [s]
# over the limit!
# 105 set, 2 slot: 3.62 [s]
# over the limit!
# 106 set, 30 slot: 4.22 [s]
# over the limit!
# 107 set, 21 slot: 3.92 [s]
# over the limit!
# 103 set, 11 slot: 3.8 [s]
# over the limit!
# 104 set, 15 slot: 3.26 [s]
# over the limit!
# 105 set, 0 slot: 3.4 [s]
# over the limit!
# 106 set, 6 slot: 4.06 [s]
# over the limit!
# 105 set, 25 slot: 3.28 [s]
# over the limit!
# 106 set, 1 slot: 3.59 [s]
# over the limit!
# 107 set, 29 slot: 3.74 [s]
# over the limit!
# 106 set, 24 slot: 3.41 [s]
# over the limit!
# 107 set, 5 slot: 3.36 [s]
# over the limit!
# 108 set, 8 slot: 3.69 [s]
# over the limit!
# 109 set, 13 slot: 3.5 [s]
# over the limit!
# 110 set, 17 slot: 3.4 [s]
# over the limit!
# 107 set, 9 slot: 3.62 [s]
# over the limit!
# 108 set, 16 slot: 3.39 [s]
# over the limit!
# 109 set, 14 slot: 3.29 [s]
# over the limit!
# 110 set, 10 slot: 3.24 [s]
# over the limit!
# 111 set, 22 slot: 3.52 [s]
# over the limit!
# 112 set, 23 slot: 4.06 [s]
# over the limit!
# 108 set, 26 slot: 3.75 [s]
# over the limit!
# 109 set, 18 slot: 3.36 [s]
# over the limit!
# 110 set, 2 slot: 3.26 [s]
# over the limit!
# 111 set, 3 slot: 3.57 [s]
# crashed to ground
# 109 set, 10 slot: 1.01 [s]
# over the limit!
# 110 set, 7 slot: 3.66 [s]
# over the limit!
# 111 set, 0 slot: 3.27 [s]
# over the limit!
# 110 set, 4 slot: 4.55 [s]
# over the limit!
# 111 set, 27 slot: 3.94 [s]
# over the limit!
# 112 set, 28 slot: 3.93 [s]
# over the limit!
# 113 set, 11 slot: 3.71 [s]
# over the limit!
# 114 set, 19 slot: 6.0 [s]
# over the limit!
# 115 set, 21 slot: 4.06 [s]
# over the limit!
# 111 set, 31 slot: 5.7 [s]
# over the limit!
# 112 set, 6 slot: 4.43 [s]
# over the limit!
# 113 set, 1 slot: 3.67 [s]
# over the limit!
# 114 set, 29 slot: 3.48 [s]
# over the limit!
# 115 set, 15 slot: 4.91 [s]
