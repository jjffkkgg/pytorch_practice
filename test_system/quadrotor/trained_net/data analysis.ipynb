# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('flight_data.npy')
distance = np.load('distance_data.npy')

# %%
t = np.arange(0, size/100, 0.01)
size = distance[0,:].size
start = np.array([0,0,0])
stop = np.array([10,10,10])

traj = np.linspace(start, stop, size)

# %%
plt.figure(1)
plt.plot(t,distance[31,:])
plt.grid()

# %%
index = 3

fig2 = plt.figure(num = 2, figsize=(16,9))
ax1 = fig2.add_subplot(2, 3, 1)
plt.plot(data[index,:,9],
            data[index,:,10])
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.title('x-y Postition')
plt.xlabel('X axis [m]')
plt.ylabel('Y axis [m]')
plt.grid()

ax2 = fig2.add_subplot(2, 3, 2)
plt.plot(t,data[index,:,11])
plt.title('Height')
plt.xlabel('Time [s]')
plt.ylabel('Height [m]')
plt.grid()

ax3 = fig2.add_subplot(2, 3, 3)
plt.plot(t,data[index,:,6]*180/np.pi,
            t,data[index,:,7]*180/np.pi,
            t,data[index,:,8]*180/np.pi)
plt.title('Angle')
plt.xlabel('Time [s]')
plt.ylabel('Angle [deg]')
plt.legend(['x(phi)','y(theta)','z(psi)'])
plt.grid()

ax4 = fig2.add_subplot(2, 3, 4)
plt.plot(t, data[index,:,0]*180/np.pi,
            t, data[index,:,1]*180/np.pi,
            t, data[index,:,2]*180/np.pi)
plt.title('Angular Velocity(body)')
plt.xlabel('Time [s]')
plt.ylabel('Angular Velocity(body) [deg/s]')
plt.legend(['x(phi)','y(theta)','z(psi)'])
plt.grid()

ax5 = fig2.add_subplot(2, 3, 5)
plt.plot(t,distance[index,:])
plt.title('Distance off from guided trajectory')
plt.xlabel('Time [s]')
plt.ylabel('Distance [m]')
plt.grid()

ax6 = fig2.add_subplot(2,3,6)
plt.plot(t, data[index,:,3],
            t, data[index,:,4],
            t, data[index,:,5])
plt.title('Velocity')
plt.xlabel('Time [s]')
plt.ylabel('Velocity [m/s]')
plt.grid()
