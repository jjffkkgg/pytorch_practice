# %%
'''
env = gym.make('CartPole-v0')
env.reset()
random_episodes = 0
reward_sum = 0
while random_episodes < 10:
    env.render()
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)
    print(observation, reward, done)
    reward_sum += reward
    if done:
        random_episodes += 1
        print(f"Reward for this episode was: {reward_sum}")
        reward_sum = 0
        env.reset()
env.close()
'''

# %%
from __future__ import annotations
from collections import namedtuple
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import gym

# %%
Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# set env with setting (especially reward and max episode)
gym.envs.register(
    id='CartPole_prefer-v0',
    entry_point='gym.envs.classic_control:CartPoleEnv',
    max_episode_steps=700,      # CartPole-v0 uses 200
    reward_threshold=-110.0,
)

# 상수 정의
ENV = 'CartPole_prefer-v0'     # 태스크 이름
GAMMA = 0.99            # 시간할인율
MAX_STEPS = 700         # 1에피소드 당 최대 단계 수
NUM_EPISODES = 2000      # 최대 에피소드 수
BATCH_SIZE = 32
capacity = 10000        # Memory capacity

# %%
# 애니메이션을 만드는 함수
# 참고 URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    # anim.save('movie_cartpole_DQN.mp4')  # 애니메이션을 저장하는 부분
    anim.save('cartpole_DQN.gif', writer='ImageMagick', fps=60)
    display(display_animation(anim, default_mode='loop'))

# %%
class ReplayMemory:
    ''' Memory for random selection of trials '''
    
    def __init__(self, capacity: int) -> None:
        self.capacity = capacity    # Memory capacity
        self.memory = []            # Transition memory
        self.index = 0              # indicate saving location
        
    def push(self, state: torch.FloatTensor, action: torch.LongTensor,
             state_next: torch.FloatTensor, reward: torch.FloatTensor) -> None:
        '''Transition~(s,a,s_n,r) 메모리 저장'''
        if len(self.memory) < self.capacity:                                        # case memory not full
            self.memory.append(None)                                                # increase size of list to avoid index error
        
        self.memory[self.index] = Transition(state, action, state_next, reward)     # add namedtuple Transition
        self.index = (self.index + 1) % self.capacity                               # increase index (keep update over episode)
        
    def sample(self, batch_size: int) -> list:
        '''replay 메모리에서 batch size 만큼 Transition 랜덤 뽑기'''
        return random.sample(self.memory, batch_size)
    
    def __len__(self) -> int:
        '''return saved Transitions'''
        return len(self.memory)

# %%
class Net(nn.Module):

    def __init__(self,n_in: int, n_mid: int, n_out: int):  
        super(Net, self).__init__()  
        self.fc1 = nn.Linear(n_in, n_mid)  
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)  

    def forward(self, x):  
        x1 = F.relu(self.fc1(x))  
        x2 = F.relu(self.fc2(x1))
        out = self.fc3(x2)
        return out

# %%
class TrainNet:
    ''' Where weights are optimized'''
    def __init__(self,num_states: int, num_actions: int) -> None:
        '''Initialize network models'''
        self.num_states = num_states
        self.num_actions = num_actions
        
        self.mem = ReplayMemory(capacity)                           # Initialize ReplayMem

        n_in, n_mid, n_out = num_states, 32, num_actions
        self.policy_net = Net(n_in, n_mid, n_out)                   # create policy(main) net
        self.target_net = Net(n_in, n_mid, n_out)                   # create target net
        print(self.policy_net)                                           # print out the model
        
        # Selection of gradient descent model.(i.e. SGD, RMSprop, Adagrad,...)
        # change weight coeffs of network with gradient descent of params
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr = 0.0001)

    def replay(self) -> None:
        '''REPLAY OF MEMORY & TRAIN OF NETWORK'''
    # -----------------------------------------
    # 1. 저장된 transition 수 확인
    # -----------------------------------------
        # 1.1 저장된 transition의 수가 미니배치 크기보다 작으면 아무 것도 하지 않음
        if len(self.mem) < BATCH_SIZE:
            return None
        # 2. 미니배치 생성
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_state = self.make_minibatch()

        # 3. expected_Q 계산
        self.expected_Q = self.get_expected_Q()

        # 4. 결합 가중치 수정 (정책망 업데이트)
        self.update_policynet()
    

    def make_minibatch(self) -> list:
    # -----------------------------------------
    #  미니배치 생성
    # -----------------------------------------
        # 1 메모리 객체에서 미니배치를 추출
        trans_sample = self.mem.sample(BATCH_SIZE)

        # 2 각 변수를 미니배치에 맞는 형태로 변형
        # trans_sample 은 각 단계 별로 (state, action, state_next, reward) 형태로 BATCH_SIZE 갯수만큼 저장됨
        # 다시 말해, (state, action, state_next, reward) * BATCH_SIZE 형태가 된다
        # 이것을 미니배치로 만들기 위해
        # (state*BATCH_SIZE, action*BATCH_SIZE, state_next*BATCH_SIZE, reward*BATCH_SIZE) 형태로 변환한다
        batch = Transition(*zip(*trans_sample))
    
        # 3 각 변수의 요소를 미니배치에 맞게 변형하고, 신경망으로 다룰 수 있도록 Variable로 만든다
        # state를 예로 들면, [torch.FloatTensor of size 1*4] 형태의 요소가 BATCH_SIZE 갯수만큼 있는 형태이다
        # 이를 torch.FloatTensor of size BATCH_SIZE*4 형태로 변형한다
        # 상태, 행동, 보상, non_final 상태로 된 미니배치를 나타내는 Variable을 생성
        # cat은 Concatenates을 의미한다
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_state = torch.cat([s for s in batch.next_state if s is not None])
        return batch, state_batch, action_batch, reward_batch, non_final_next_state
        
    
    def get_expected_Q(self):
    # -----------------------------------------BBBBBBBBBBB
    # 정답신호로 사용할 Q(s_t, a_t)를 계산
    # -----------------------------------------
        # 1 신경망을 추론 모드로 전환
        self.policy_net.eval()
        self.target_net.eval()

        # 2 신경망으로 Q(s_t, a_t)를 계산
        # self.model(state_batch)은 왼쪽, 오른쪽에 대한 Q값을 출력하며
        # [torch.FloatTensor of size BATCH_SIZEx2] 형태이다
        # 여기서부터는 실행한 행동 a_t에 대한 Q값을 계산하므로 action_batch에서 취한 행동 a_t가 
        # 왼쪽이냐 오른쪽이냐에 대한 인덱스를 구하고, 이에 대한 Q값을 gather 메서드로 모아온다
        self.Q = self.policy_net(self.state_batch).gather(1, self.action_batch)

        # 3 max{Q(s_t+1, a)}값을 계산한다 이때 다음 상태가 존재하는지에 주의해야 한다
        # cartpole이 done 상태가 아니고, next_state가 존재하는지 확인하는 인덱스 마스크를 만듬
        # lamba & map -> https://offbyone.tistory.com/73
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))

        # 먼저 전체를 0으로 초기화
        next_Q = torch.zeros(BATCH_SIZE)
        action_max = torch.zeros(BATCH_SIZE).type(torch.LongTensor)    # 다음 상태에서 Q값이 최대가 되는 행동

        # 다음 상태에서 Q값이 최대가 되는 행동 action_max을 Main Q-Network로 계산
        # 마지막에 붙은 [1]로 행동에 해당하는 인덱스를 구함
        action_max[non_final_mask] = self.policy_net(self.non_final_next_state).max(1)[1].detach()

        # 다음 상태가 있는 것만을 걸러내고, size 32를 32*1로 변환
        action_max_non_final_next_state = action_max[non_final_mask].view(-1, 1)
        
        # 다음 상태가 있는 인덱스에 대해 행동 action_max의 Q값을 target Q-Network로 계산
        # policy net 에서 나타난 nextQmax 에 해당하는 action을 target net 으로 갖고와 따로 계산함.
        # detach() 메서드로 값을 꺼내옴
        # squeeze() 메서드로 size[minibatch*1]을 [minibatch]로 변환
        next_Q[non_final_mask] = self.target_net(self.non_final_next_state).gather(1, action_max_non_final_next_state).detach().squeeze()

        # 3.4 정답신호로 사용할 Q(s_t, a_t)값을 Q러닝 식으로 계산한다
        expected_Q = self.reward_batch + GAMMA * next_Q

        return expected_Q

    def update_policynet(self):
    # -----------------------------------------
    #  결합 가중치 수정
    # -----------------------------------------
        # 1 신경망을 학습 모드로 전환
        self.policy_net.train()

        # 2 손실함수를 계산 (smooth_l1_loss는 Huber 함수)
        # expected_Q는 size가 [minibatch]이므로 unsqueeze하여 [minibatch*1]로 만든다
        loss = F.smooth_l1_loss(self.Q, self.expected_Q.unsqueeze(1))

        # 3 결합 가중치를 수정한다
        self.optimizer.zero_grad()      # Initialize gradient(경사)
        loss.backward()                 # Calculate backward(역전파 계산)
        self.optimizer.step()           # perform single optimize step (가중치 수정)
    
    def update_targetnet(self):
    # -----------------------------------------
    #  Target net 을 Policy net 과 동기화(주기적)
    # -----------------------------------------
        self.target_net.load_state_dict(self.policy_net.state_dict())   # load_state_dict -> copies all state params & buffers from attribute


    def decide_action(self, state: torch.FloatTensor, episode: int) -> torch.LongTensor:
        '''Decision of action with \epsilon greedy'''
        epsilon = 0.5 * (1 / (episode + 1))                         # epsilon decay
        if epsilon <= np.random.uniform(0,1):                           # weighted action
            self.policy_net.eval()                                           # change network mode to inference
            with torch.no_grad():
                action = self.policy_net(state).max(1)[1].view(1,1)
                # 신경망 출력의 최댓값에 대한 인덱스(action) = max(1)[1]
                # .view(1,1)은 [torch.LongTensor of size 1] 을 size 1*1로 변환하는 역할을 한다

        else:                                                           # random action
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])                 # return 0 or 1 (LongTensor of size 1*1)

        return action

# %%
class Environment:
    ''' Initialize and run the environment '''
    
    def __init__(self) -> None:
        self.env = gym.make(ENV)                                # env set
        num_states = self.env.observation_space.shape[0]        # Get State shape (4)
        num_actions = self.env.action_space.n                   # Get action numbers (2)
        self.train = TrainNet(num_states,num_actions)          # Initialize Network Class

        
    def run(self) -> None:
        '''Run and update iteration'''
        episode_10_list = np.zeros(10)                          # Save steps succeeded for last 10 episodes
        complete_episodes = 0                                   # Episodes number that reached goal
        is_episode_final = False                                # did it succeeded for 10 episodes? (terminate)
        frames = []                                             # frame for animation

        for episode in range(NUM_EPISODES):                         # Episode iteration (single train per episode)
            observation = self.env.reset()                          # reset env (=initialize)
            state = observation                                     # state <- initialized env
            state = torch.from_numpy(state).type(
                torch.FloatTensor)                                  # convert np.array -> FloatTensor
            state = torch.unsqueeze(state, 0)                       # size 4 -> size 1*4 convert

            for step in range(MAX_STEPS):                           # Iterate through max action(or state) per episode
                
                if is_episode_final is True:                              # If the goal reached
                    frames.append(self.env.render(
                        mode = 'rgb_array'))                              # Save result of final episode with frame
                
                action = self.train.decide_action(state, episode) # determine action through eps-greedy

                new_observation, _, done, _ = self.env.step(
                    action.item())                                  # get new state from decided action (reward & info -> blank)

                if done:                                                # if pole lean down || iteration > max_episode_steps 
                    new_state = None                                    # No new state
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))                # save succeeded steps by every 'episode'
                    
                    if step < (MAX_STEPS - 5):                                # if pole lean down( < max_episode_steps)
                        reward = torch.FloatTensor([-1.0])                  # reward -> -1
                        complete_episodes = 0                               # reset complete_episode
                    else:                                                   # if pole does not lean down
                        reward = torch.FloatTensor([1.0])                   # reward -> 1
                        complete_episodes += 1                              # update succeeded number
                else:                                                   # not done(still in interation)
                    reward = torch.FloatTensor([0.0])                   # reward = 0
                    new_state = new_observation                         # update new state
                    new_state = torch.from_numpy(new_state).type(           # change type to FloatTensor
                        torch.FloatTensor)
                    new_state = torch.unsqueeze(new_state, 0)           # size 4 -> size 1*4 convert

                self.train.mem.push(
                    state, action, new_state, reward)               # store iteration information(Transition) into memory
                self.train.replay()                               # update Q with Experience Replay
                state = new_state                                   # update state

                if done:
                    print(f'{episode} Episode: Finished after {step + 1} steps：최근 10 에피소드의 평균 단계 수 = {episode_10_list.mean()}')
                
                    if (episode % 2 == 0):                                  # Every 2 episode, after done of step, update the target net to policy net
                        self.train.update_targetnet()
                    break

            if is_episode_final is True:
                display_frames_as_gif(frames)                   # save result as gif
                break

            if complete_episodes >= 10:                         # (iteration > max_episode_steps) && (pole does not lean down) for 10 episodes
                print('10 에피소드 연속 성공')
                is_episode_final = True                        # save result and break
                
        if is_episode_final is False:                       #print if failed
            print('학습 실패')

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 2.8
# 1 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 4.6
# 2 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 6.1
# 3 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 7.4
# 4 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 8.8
# 5 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 10.2
# <ipython-input-7-0129f011b421>:89: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   action_max[non_final_mask] = self.policy_net(self.non_final_next_state).max(1)[1].detach()
# <ipython-input-7-0129f011b421>:92: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   action_max_non_final_next_state = action_max[non_final_mask].view(-1, 1)
# <ipython-input-7-0129f011b421>:98: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   next_Q[non_final_mask] = self.target_net(self.non_final_next_state).gather(1, action_max_non_final_next_state).detach().squeeze()
# 6 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 11.3
# 7 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 12.5
# 8 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 13.8
# 9 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 14.8
# 10 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 12.9
# 11 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 12.2
# 12 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 11.6
# 13 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 11.3
# 14 Episode: Finished after 8 steps：최근 10 에피소드의 평균 단계 수 = 10.7
# 15 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.3
# 16 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.2
# 17 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 10.2
# 18 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.9
# 19 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.9
# 20 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.0
# 21 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.9
# 22 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.9
# 23 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.8
# 24 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.0
# 25 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.9
# 26 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.8
# 27 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.5
# 28 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.5
# 29 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.5
# 30 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 31 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 32 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.6
# 33 Episode: Finished after 8 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 34 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 10.4
# 35 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 36 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 37 Episode: Finished after 8 steps：최근 10 에피소드의 평균 단계 수 = 10.4
# 38 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 10.6
# 39 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 40 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.5
# 41 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.4
# 42 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.3
# 43 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 9.6
# 44 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.7
# 45 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 10.0
# 46 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 10.0
# 47 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.2
# 48 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 10.1
# 49 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 10.3
# 50 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 10.4
# 51 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 52 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.6
# 53 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 10.8
# 54 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 11.1
# 55 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 10.9
# 56 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 11.3
# 57 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 11.9
# 58 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 12.0
# 59 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 12.7
# 60 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 13.6
# 61 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 14.1
# 62 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 14.2
# 63 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 14.0
# 64 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 14.3
# 65 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 15.1
# 66 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 15.0
# 67 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 15.3
# 68 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 15.7
# 69 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 15.4
# 70 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 15.3
# 71 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 15.1
# 72 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 15.4
# 73 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 15.8
# 74 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 16.2
# 75 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 16.4
# 76 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 16.7
# 77 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 17.0
# 78 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 17.1
# 79 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 17.5
# 80 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 17.0
# 81 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 17.9
# 82 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 18.2
# 83 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 19.0
# 84 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 19.1
# 85 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 18.8
# 86 Episode: Finished after 38 steps：최근 10 에피소드의 평균 단계 수 = 21.1
# 87 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 21.7
# 88 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 22.2
# 89 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 22.1
# 90 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 23.2
# 91 Episode: Finished after 30 steps：최근 10 에피소드의 평균 단계 수 = 24.0
# 92 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 25.1
# 93 Episode: Finished after 36 steps：최근 10 에피소드의 평균 단계 수 = 26.4
# 94 Episode: Finished after 44 steps：최근 10 에피소드의 평균 단계 수 = 28.7
# 95 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 28.9
# 96 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 27.0
# 97 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 27.7
# 98 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 27.8
# 99 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 29.5
# 100 Episode: Finished after 37 steps：최근 10 에피소드의 평균 단계 수 = 30.7
# 101 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 30.1
# 102 Episode: Finished after 48 steps：최근 10 에피소드의 평균 단계 수 = 32.1
# 103 Episode: Finished after 50 steps：최근 10 에피소드의 평균 단계 수 = 33.5
# 104 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 31.5
# 105 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 32.6
# 106 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 34.8
# 107 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 35.4
# 108 Episode: Finished after 49 steps：최근 10 에피소드의 평균 단계 수 = 38.0
# 109 Episode: Finished after 57 steps：최근 10 에피소드의 평균 단계 수 = 40.2
# 110 Episode: Finished after 77 steps：최근 10 에피소드의 평균 단계 수 = 44.2
# 111 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 45.9
# 112 Episode: Finished after 56 steps：최근 10 에피소드의 평균 단계 수 = 46.7
# 113 Episode: Finished after 130 steps：최근 10 에피소드의 평균 단계 수 = 54.7
# 114 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 55.8
# 115 Episode: Finished after 44 steps：최근 10 에피소드의 평균 단계 수 = 57.1
# 116 Episode: Finished after 59 steps：최근 10 에피소드의 평균 단계 수 = 58.9
# 117 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 57.3
# 118 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 54.7
# 119 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 53.1
# 120 Episode: Finished after 59 steps：최근 10 에피소드의 평균 단계 수 = 51.3
# 121 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 51.3
# 122 Episode: Finished after 39 steps：최근 10 에피소드의 평균 단계 수 = 49.6
# 123 Episode: Finished after 38 steps：최근 10 에피소드의 평균 단계 수 = 40.4
# 124 Episode: Finished after 38 steps：최근 10 에피소드의 평균 단계 수 = 40.7
# 125 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 39.5
# 126 Episode: Finished after 36 steps：최근 10 에피소드의 평균 단계 수 = 37.2
# 127 Episode: Finished after 118 steps：최근 10 에피소드의 평균 단계 수 = 46.5
# 128 Episode: Finished after 103 steps：최근 10 에피소드의 평균 단계 수 = 54.5
# 129 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 53.1
# 130 Episode: Finished after 36 steps：최근 10 에피소드의 평균 단계 수 = 50.8
# 131 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 49.4
# 132 Episode: Finished after 37 steps：최근 10 에피소드의 평균 단계 수 = 49.2
# 133 Episode: Finished after 26 steps：최근 10 에피소드의 평균 단계 수 = 48.0
# 134 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 47.7
# 135 Episode: Finished after 87 steps：최근 10 에피소드의 평균 단계 수 = 53.2
# 136 Episode: Finished after 58 steps：최근 10 에피소드의 평균 단계 수 = 55.4
# 137 Episode: Finished after 66 steps：최근 10 에피소드의 평균 단계 수 = 50.2
# 138 Episode: Finished after 46 steps：최근 10 에피소드의 평균 단계 수 = 44.5
# 139 Episode: Finished after 95 steps：최근 10 에피소드의 평균 단계 수 = 51.3
# 140 Episode: Finished after 47 steps：최근 10 에피소드의 평균 단계 수 = 52.4
# 141 Episode: Finished after 34 steps：최근 10 에피소드의 평균 단계 수 = 53.1
# 142 Episode: Finished after 48 steps：최근 10 에피소드의 평균 단계 수 = 54.2
# 143 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 54.4
# 144 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 55.0
# 145 Episode: Finished after 46 steps：최근 10 에피소드의 평균 단계 수 = 50.9
# 146 Episode: Finished after 54 steps：최근 10 에피소드의 평균 단계 수 = 50.5
# 147 Episode: Finished after 57 steps：최근 10 에피소드의 평균 단계 수 = 49.6
# 148 Episode: Finished after 47 steps：최근 10 에피소드의 평균 단계 수 = 49.7
# 149 Episode: Finished after 48 steps：최근 10 에피소드의 평균 단계 수 = 45.0
# 150 Episode: Finished after 65 steps：최근 10 에피소드의 평균 단계 수 = 46.8
# 151 Episode: Finished after 34 steps：최근 10 에피소드의 평균 단계 수 = 46.8
# 152 Episode: Finished after 85 steps：최근 10 에피소드의 평균 단계 수 = 50.5
# 153 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 51.8
# 154 Episode: Finished after 54 steps：최근 10 에피소드의 평균 단계 수 = 53.1
# 155 Episode: Finished after 51 steps：최근 10 에피소드의 평균 단계 수 = 53.6
# 156 Episode: Finished after 43 steps：최근 10 에피소드의 평균 단계 수 = 52.5
# 157 Episode: Finished after 48 steps：최근 10 에피소드의 평균 단계 수 = 51.6
# 158 Episode: Finished after 38 steps：최근 10 에피소드의 평균 단계 수 = 50.7
# 159 Episode: Finished after 90 steps：최근 10 에피소드의 평균 단계 수 = 54.9
# 160 Episode: Finished after 50 steps：최근 10 에피소드의 평균 단계 수 = 53.4
# 161 Episode: Finished after 42 steps：최근 10 에피소드의 평균 단계 수 = 54.2
# 162 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 49.8
# 163 Episode: Finished after 78 steps：최근 10 에피소드의 평균 단계 수 = 53.5
# 164 Episode: Finished after 58 steps：최근 10 에피소드의 평균 단계 수 = 53.9
# 165 Episode: Finished after 46 steps：최근 10 에피소드의 평균 단계 수 = 53.4
# 166 Episode: Finished after 118 steps：최근 10 에피소드의 평균 단계 수 = 60.9
# 167 Episode: Finished after 44 steps：최근 10 에피소드의 평균 단계 수 = 60.5
# 168 Episode: Finished after 75 steps：최근 10 에피소드의 평균 단계 수 = 64.2
# 169 Episode: Finished after 95 steps：최근 10 에피소드의 평균 단계 수 = 64.7
# 170 Episode: Finished after 58 steps：최근 10 에피소드의 평균 단계 수 = 65.5
# 171 Episode: Finished after 61 steps：최근 10 에피소드의 평균 단계 수 = 67.4
# 172 Episode: Finished after 57 steps：최근 10 에피소드의 평균 단계 수 = 69.0
# 173 Episode: Finished after 84 steps：최근 10 에피소드의 평균 단계 수 = 69.6
# 174 Episode: Finished after 88 steps：최근 10 에피소드의 평균 단계 수 = 72.6
# 175 Episode: Finished after 62 steps：최근 10 에피소드의 평균 단계 수 = 74.2
# 176 Episode: Finished after 73 steps：최근 10 에피소드의 평균 단계 수 = 69.7
# 177 Episode: Finished after 74 steps：최근 10 에피소드의 평균 단계 수 = 72.7
# 178 Episode: Finished after 69 steps：최근 10 에피소드의 평균 단계 수 = 72.1
# 179 Episode: Finished after 63 steps：최근 10 에피소드의 평균 단계 수 = 68.9
# 180 Episode: Finished after 87 steps：최근 10 에피소드의 평균 단계 수 = 71.8
# 181 Episode: Finished after 90 steps：최근 10 에피소드의 평균 단계 수 = 74.7
# 182 Episode: Finished after 103 steps：최근 10 에피소드의 평균 단계 수 = 79.3
# 183 Episode: Finished after 92 steps：최근 10 에피소드의 평균 단계 수 = 80.1
# 184 Episode: Finished after 89 steps：최근 10 에피소드의 평균 단계 수 = 80.2
# 185 Episode: Finished after 77 steps：최근 10 에피소드의 평균 단계 수 = 81.7
# 186 Episode: Finished after 77 steps：최근 10 에피소드의 평균 단계 수 = 82.1
# 187 Episode: Finished after 84 steps：최근 10 에피소드의 평균 단계 수 = 83.1
# 188 Episode: Finished after 97 steps：최근 10 에피소드의 평균 단계 수 = 85.9
# 189 Episode: Finished after 101 steps：최근 10 에피소드의 평균 단계 수 = 89.7
# 190 Episode: Finished after 138 steps：최근 10 에피소드의 평균 단계 수 = 94.8
# 191 Episode: Finished after 98 steps：최근 10 에피소드의 평균 단계 수 = 95.6
# 192 Episode: Finished after 99 steps：최근 10 에피소드의 평균 단계 수 = 95.2
# 193 Episode: Finished after 391 steps：최근 10 에피소드의 평균 단계 수 = 125.1
# 194 Episode: Finished after 95 steps：최근 10 에피소드의 평균 단계 수 = 125.7
# 195 Episode: Finished after 105 steps：최근 10 에피소드의 평균 단계 수 = 128.5
# 196 Episode: Finished after 113 steps：최근 10 에피소드의 평균 단계 수 = 132.1
# 197 Episode: Finished after 119 steps：최근 10 에피소드의 평균 단계 수 = 135.6
# 198 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 195.9
# 199 Episode: Finished after 158 steps：최근 10 에피소드의 평균 단계 수 = 201.6
# 200 Episode: Finished after 146 steps：최근 10 에피소드의 평균 단계 수 = 202.4
# 201 Episode: Finished after 408 steps：최근 10 에피소드의 평균 단계 수 = 233.4
# 202 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 293.5
# 203 Episode: Finished after 181 steps：최근 10 에피소드의 평균 단계 수 = 272.5
# 204 Episode: Finished after 597 steps：최근 10 에피소드의 평균 단계 수 = 322.7
# 205 Episode: Finished after 401 steps：최근 10 에피소드의 평균 단계 수 = 352.3
# 206 Episode: Finished after 140 steps：최근 10 에피소드의 평균 단계 수 = 355.0
# 207 Episode: Finished after 677 steps：최근 10 에피소드의 평균 단계 수 = 410.8
# 208 Episode: Finished after 402 steps：최근 10 에피소드의 평균 단계 수 = 381.0
# 209 Episode: Finished after 347 steps：최근 10 에피소드의 평균 단계 수 = 399.9
# 210 Episode: Finished after 260 steps：최근 10 에피소드의 평균 단계 수 = 411.3
# 211 Episode: Finished after 654 steps：최근 10 에피소드의 평균 단계 수 = 435.9
# 212 Episode: Finished after 186 steps：최근 10 에피소드의 평균 단계 수 = 384.5
# 213 Episode: Finished after 224 steps：최근 10 에피소드의 평균 단계 수 = 388.8
# 214 Episode: Finished after 101 steps：최근 10 에피소드의 평균 단계 수 = 339.2
# 215 Episode: Finished after 113 steps：최근 10 에피소드의 평균 단계 수 = 310.4
# 216 Episode: Finished after 158 steps：최근 10 에피소드의 평균 단계 수 = 312.2
# 217 Episode: Finished after 256 steps：최근 10 에피소드의 평균 단계 수 = 270.1
# 218 Episode: Finished after 215 steps：최근 10 에피소드의 평균 단계 수 = 251.4
# 219 Episode: Finished after 109 steps：최근 10 에피소드의 평균 단계 수 = 227.6
# 220 Episode: Finished after 209 steps：최근 10 에피소드의 평균 단계 수 = 222.5
# 221 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 227.1
# 222 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 278.5
# 223 Episode: Finished after 461 steps：최근 10 에피소드의 평균 단계 수 = 302.2
# 224 Episode: Finished after 179 steps：최근 10 에피소드의 평균 단계 수 = 310.0
# 225 Episode: Finished after 138 steps：최근 10 에피소드의 평균 단계 수 = 312.5
# 226 Episode: Finished after 373 steps：최근 10 에피소드의 평균 단계 수 = 334.0
# 227 Episode: Finished after 153 steps：최근 10 에피소드의 평균 단계 수 = 323.7
# 228 Episode: Finished after 164 steps：최근 10 에피소드의 평균 단계 수 = 318.6
# 229 Episode: Finished after 181 steps：최근 10 에피소드의 평균 단계 수 = 325.8
# 230 Episode: Finished after 146 steps：최근 10 에피소드의 평균 단계 수 = 319.5
# 231 Episode: Finished after 297 steps：최근 10 에피소드의 평균 단계 수 = 279.2
# 232 Episode: Finished after 171 steps：최근 10 에피소드의 평균 단계 수 = 226.3
# 233 Episode: Finished after 166 steps：최근 10 에피소드의 평균 단계 수 = 196.8
# 234 Episode: Finished after 170 steps：최근 10 에피소드의 평균 단계 수 = 195.9
# 235 Episode: Finished after 258 steps：최근 10 에피소드의 평균 단계 수 = 207.9
# 236 Episode: Finished after 128 steps：최근 10 에피소드의 평균 단계 수 = 183.4
# 237 Episode: Finished after 162 steps：최근 10 에피소드의 평균 단계 수 = 184.3
# 238 Episode: Finished after 121 steps：최근 10 에피소드의 평균 단계 수 = 180.0
# 239 Episode: Finished after 131 steps：최근 10 에피소드의 평균 단계 수 = 175.0
# 240 Episode: Finished after 168 steps：최근 10 에피소드의 평균 단계 수 = 177.2
# 241 Episode: Finished after 136 steps：최근 10 에피소드의 평균 단계 수 = 161.1
# 242 Episode: Finished after 109 steps：최근 10 에피소드의 평균 단계 수 = 154.9
# 243 Episode: Finished after 135 steps：최근 10 에피소드의 평균 단계 수 = 151.8
# 244 Episode: Finished after 126 steps：최근 10 에피소드의 평균 단계 수 = 147.4
# 245 Episode: Finished after 128 steps：최근 10 에피소드의 평균 단계 수 = 134.4
# 246 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 134.9
# 247 Episode: Finished after 118 steps：최근 10 에피소드의 평균 단계 수 = 130.5
# 248 Episode: Finished after 140 steps：최근 10 에피소드의 평균 단계 수 = 132.4
# 249 Episode: Finished after 117 steps：최근 10 에피소드의 평균 단계 수 = 131.0
# 250 Episode: Finished after 115 steps：최근 10 에피소드의 평균 단계 수 = 125.7
# 251 Episode: Finished after 131 steps：최근 10 에피소드의 평균 단계 수 = 125.2
# 252 Episode: Finished after 116 steps：최근 10 에피소드의 평균 단계 수 = 125.9
# 253 Episode: Finished after 110 steps：최근 10 에피소드의 평균 단계 수 = 123.4
# 254 Episode: Finished after 107 steps：최근 10 에피소드의 평균 단계 수 = 121.5
# 255 Episode: Finished after 126 steps：최근 10 에피소드의 평균 단계 수 = 121.3
# 256 Episode: Finished after 132 steps：최근 10 에피소드의 평균 단계 수 = 121.2
# 257 Episode: Finished after 150 steps：최근 10 에피소드의 평균 단계 수 = 124.4
# 258 Episode: Finished after 128 steps：최근 10 에피소드의 평균 단계 수 = 123.2
# 259 Episode: Finished after 116 steps：최근 10 에피소드의 평균 단계 수 = 123.1
# 260 Episode: Finished after 128 steps：최근 10 에피소드의 평균 단계 수 = 124.4
# 261 Episode: Finished after 264 steps：최근 10 에피소드의 평균 단계 수 = 137.7
# 262 Episode: Finished after 151 steps：최근 10 에피소드의 평균 단계 수 = 141.2
# 263 Episode: Finished after 153 steps：최근 10 에피소드의 평균 단계 수 = 145.5
# 264 Episode: Finished after 151 steps：최근 10 에피소드의 평균 단계 수 = 149.9
# 265 Episode: Finished after 174 steps：최근 10 에피소드의 평균 단계 수 = 154.7
# 266 Episode: Finished after 122 steps：최근 10 에피소드의 평균 단계 수 = 153.7
# 267 Episode: Finished after 179 steps：최근 10 에피소드의 평균 단계 수 = 156.6
# 268 Episode: Finished after 121 steps：최근 10 에피소드의 평균 단계 수 = 155.9
# 269 Episode: Finished after 142 steps：최근 10 에피소드의 평균 단계 수 = 158.5
# 270 Episode: Finished after 191 steps：최근 10 에피소드의 평균 단계 수 = 164.8
# 271 Episode: Finished after 131 steps：최근 10 에피소드의 평균 단계 수 = 151.5
# 272 Episode: Finished after 152 steps：최근 10 에피소드의 평균 단계 수 = 151.6
# 273 Episode: Finished after 145 steps：최근 10 에피소드의 평균 단계 수 = 150.8
# 274 Episode: Finished after 194 steps：최근 10 에피소드의 평균 단계 수 = 155.1
# 275 Episode: Finished after 198 steps：최근 10 에피소드의 평균 단계 수 = 157.5
# 276 Episode: Finished after 159 steps：최근 10 에피소드의 평균 단계 수 = 161.2
# 277 Episode: Finished after 183 steps：최근 10 에피소드의 평균 단계 수 = 161.6
# 278 Episode: Finished after 142 steps：최근 10 에피소드의 평균 단계 수 = 163.7
# 279 Episode: Finished after 186 steps：최근 10 에피소드의 평균 단계 수 = 168.1
# 280 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 162.3
# 281 Episode: Finished after 185 steps：최근 10 에피소드의 평균 단계 수 = 167.7
# 282 Episode: Finished after 151 steps：최근 10 에피소드의 평균 단계 수 = 167.6
# 283 Episode: Finished after 148 steps：최근 10 에피소드의 평균 단계 수 = 167.9
# 284 Episode: Finished after 159 steps：최근 10 에피소드의 평균 단계 수 = 164.4
# 285 Episode: Finished after 136 steps：최근 10 에피소드의 평균 단계 수 = 158.2
# 286 Episode: Finished after 169 steps：최근 10 에피소드의 평균 단계 수 = 159.2
# 287 Episode: Finished after 156 steps：최근 10 에피소드의 평균 단계 수 = 156.5
# 288 Episode: Finished after 249 steps：최근 10 에피소드의 평균 단계 수 = 167.2
# 289 Episode: Finished after 178 steps：최근 10 에피소드의 평균 단계 수 = 166.4
# 290 Episode: Finished after 210 steps：최근 10 에피소드의 평균 단계 수 = 174.1
# 291 Episode: Finished after 174 steps：최근 10 에피소드의 평균 단계 수 = 173.0
# 292 Episode: Finished after 187 steps：최근 10 에피소드의 평균 단계 수 = 176.6
# 293 Episode: Finished after 184 steps：최근 10 에피소드의 평균 단계 수 = 180.2
# 294 Episode: Finished after 178 steps：최근 10 에피소드의 평균 단계 수 = 182.1
# 295 Episode: Finished after 203 steps：최근 10 에피소드의 평균 단계 수 = 188.8
# 296 Episode: Finished after 216 steps：최근 10 에피소드의 평균 단계 수 = 193.5
# 297 Episode: Finished after 187 steps：최근 10 에피소드의 평균 단계 수 = 196.6
# 298 Episode: Finished after 216 steps：최근 10 에피소드의 평균 단계 수 = 193.3
# 299 Episode: Finished after 183 steps：최근 10 에피소드의 평균 단계 수 = 193.8
# 300 Episode: Finished after 214 steps：최근 10 에피소드의 평균 단계 수 = 194.2
# 301 Episode: Finished after 231 steps：최근 10 에피소드의 평균 단계 수 = 199.9
# 302 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 201.2
# 303 Episode: Finished after 228 steps：최근 10 에피소드의 평균 단계 수 = 205.6
# 304 Episode: Finished after 207 steps：최근 10 에피소드의 평균 단계 수 = 208.5
# 305 Episode: Finished after 204 steps：최근 10 에피소드의 평균 단계 수 = 208.6
# 306 Episode: Finished after 240 steps：최근 10 에피소드의 평균 단계 수 = 211.0
# 307 Episode: Finished after 247 steps：최근 10 에피소드의 평균 단계 수 = 217.0
# 308 Episode: Finished after 359 steps：최근 10 에피소드의 평균 단계 수 = 231.3
# 309 Episode: Finished after 275 steps：최근 10 에피소드의 평균 단계 수 = 240.5
# 310 Episode: Finished after 236 steps：최근 10 에피소드의 평균 단계 수 = 242.7
# 311 Episode: Finished after 388 steps：최근 10 에피소드의 평균 단계 수 = 258.4
# 312 Episode: Finished after 324 steps：최근 10 에피소드의 평균 단계 수 = 270.8
# 313 Episode: Finished after 303 steps：최근 10 에피소드의 평균 단계 수 = 278.3
# 314 Episode: Finished after 295 steps：최근 10 에피소드의 평균 단계 수 = 287.1
# 315 Episode: Finished after 339 steps：최근 10 에피소드의 평균 단계 수 = 300.6
# 316 Episode: Finished after 391 steps：최근 10 에피소드의 평균 단계 수 = 315.7
# 317 Episode: Finished after 381 steps：최근 10 에피소드의 평균 단계 수 = 329.1
# 318 Episode: Finished after 305 steps：최근 10 에피소드의 평균 단계 수 = 323.7
# 319 Episode: Finished after 410 steps：최근 10 에피소드의 평균 단계 수 = 337.2
# 320 Episode: Finished after 407 steps：최근 10 에피소드의 평균 단계 수 = 354.3
# 321 Episode: Finished after 407 steps：최근 10 에피소드의 평균 단계 수 = 356.2
# 322 Episode: Finished after 435 steps：최근 10 에피소드의 평균 단계 수 = 367.3
# 323 Episode: Finished after 408 steps：최근 10 에피소드의 평균 단계 수 = 377.8
# 324 Episode: Finished after 411 steps：최근 10 에피소드의 평균 단계 수 = 389.4
# 325 Episode: Finished after 434 steps：최근 10 에피소드의 평균 단계 수 = 398.9
# 326 Episode: Finished after 383 steps：최근 10 에피소드의 평균 단계 수 = 398.1
# 327 Episode: Finished after 460 steps：최근 10 에피소드의 평균 단계 수 = 406.0
# 328 Episode: Finished after 366 steps：최근 10 에피소드의 평균 단계 수 = 412.1
# 329 Episode: Finished after 587 steps：최근 10 에피소드의 평균 단계 수 = 429.8
# 330 Episode: Finished after 533 steps：최근 10 에피소드의 평균 단계 수 = 442.4
# 331 Episode: Finished after 220 steps：최근 10 에피소드의 평균 단계 수 = 423.7
# 332 Episode: Finished after 512 steps：최근 10 에피소드의 평균 단계 수 = 431.4
# 333 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 460.6
# 334 Episode: Finished after 681 steps：최근 10 에피소드의 평균 단계 수 = 487.6
# 335 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 514.2
# 336 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 545.9
# 337 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 569.9
# 338 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 603.3
# 339 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 614.6
# 340 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 631.3
# 341 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 679.3
# 342 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 698.1
# 343 Episode: Finished after 527 steps：최근 10 에피소드의 평균 단계 수 = 680.8
# 344 Episode: Finished after 471 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 345 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 346 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 347 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 348 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 349 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 350 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 351 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 352 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 659.8
# 353 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 677.1
# 354 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 700.0
# 10 에피소드 연속 성공
# MovieWriter ImageMagick unavailable; using Pillow instead.
# 355 Episode: Finished after 700 steps：최근 10 에피소드의 평균 단계 수 = 700.0
# /home/taehwan/anaconda3/envs/pyt/lib/python3.8/site-packages/JSAnimation/html_writer.py:281: MatplotlibDeprecationWarning:
# The 'clear_temp' parameter of setup() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. If any parameter follows 'clear_temp', they should be passed as keyword, not positionally.
#   super(HTMLWriter, self).setup(fig, outfile, dpi,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-7dfab0e69a06> in <module>
#       1 cartpole_env = Environment()
# ----> 2 cartpole_env.run()
#
# <ipython-input-8-bb9dc0671fcf> in run(self)
#      65
#      66             if is_episode_final is True:
# ---> 67                 display_frames_as_gif(frames)                   # save result as gif
#      68                 break
#      69
#
# <ipython-input-4-2cfaa7357b20> in display_frames_as_gif(frames)
#      24     # anim.save('movie_cartpole_DQN.mp4')  # 애니메이션을 저장하는 부분
#      25     anim.save('cartpole_DQN.gif', writer='ImageMagick', fps=60)
# ---> 26     display(display_animation(anim, default_mode='loop'))
#      27
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/JSAnimation/IPython_display.py in display_animation(anim, **kwargs)
#      84     """Display the animation with an IPython HTML object"""
#      85     from IPython.display import HTML
# ---> 86     return HTML(anim_to_html(anim, **kwargs))
#      87
#      88
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/JSAnimation/IPython_display.py in anim_to_html(anim, fps, embed_frames, default_mode)
#      72         #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73         with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
#      76                                                  default_mode=default_mode))
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/anaconda3/envs/pyt/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     516         # Call run here now that all frame grabbing is done. All temp files
#     517         # are available to be assembled.
# --> 518         self._run()
#     519         MovieWriter.finish(self)  # Will call clean-up
#     520
#
# ~/anaconda3/envs/pyt/lib/python3.8/site-packages/JSAnimation/html_writer.py in _run(self)
#     321             of.write(JS_INCLUDE)
#     322             of.write(DISPLAY_TEMPLATE.format(id=self.new_id(),
# --> 323                                              Nframes=len(self._temp_names),
#     324                                              fill_frames=fill_frames,
#     325                                              interval=interval,
#
# AttributeError: 'HTMLWriter' object has no attribute '_temp_names'
